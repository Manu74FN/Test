# %% [markdown]
# ### Ejercicios visualización

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
air_quality = pd.read_csv("/home/manu/Desktop/Test/data/air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# ##### 1. Dibuja el histograma de alguna de los datos de la estación de París. ¿Para qué sirve el parámetro bins?

# %%
fig, axs = plt.subplots()
plt.hist(air_quality["station_paris"])
# Out:
# (array([ 43., 308., 274., 184.,  92.,  53.,  24.,  17.,   7.,   2.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
# El parámetro bins nos permite especificar los rangos que queremos representar.
# Hay que pasarle una lista con los valores mínimo y máximo de cada rango.
plt.hist(air_quality["station_paris"], bins=[1, 25, 50, 75, 100])
# Out:
# (array([519., 386.,  79.,  13.]),
#  array([  1.,  25.,  50.,  75., 100.]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ##### 2. Pon título y label al gráfico anterior

# %%
plt.hist(air_quality["station_paris"], bins=[0, 25, 50, 75, 100])
plt.title("Staiton París")
plt.ylabel("NO$_2$ concentration")
# Out:
# Text(0, 0.5, 'NO$_2$ concentration')

# %% [markdown]
# ##### 3. Haz un gráfico con la distribución de densidad de probabilidad de los datos de la estación de Londres

# %%
air_quality["station_london"].plot.density(4,5)
# Out:
# <Axes: ylabel='Density'>
